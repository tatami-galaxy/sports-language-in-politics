# %%
import polars as pl
import json
import statistics
import re
import random
from tqdm.auto import tqdm

from openai import OpenAI

# %% [markdown]
# ##### Load data

# %%
data_dir = '/Volumes/PortableSSD/CSS/data/processed/'
#data_dir = '/users/ujan/Downloads/'

# %%
data_df = pl.read_csv(data_dir+'posts_2015-21_ps_min_2c_politics.csv')
data_df.head()

# %% [markdown]
# ##### save positive posts to csv from the text files

# %%
data_dict = {'posts': [], 'exps': []}

with open(data_dir+'gpt3_pos_sample.txt') as f:
    for line in f.readlines():
        if line[0] == 'p':
            post = line.split('post : ')[-1].split('\n')[0]
            data_dict['posts'].append(post)
        elif line[0] == 'm':
            exp = line.split('meta : ')[-1].split('\n')[0]
            data_dict['exps'].append(exp)

pos_df = pl.from_dict(data_dict)
pos_df.write_csv(data_dir+'gpt3_pos_sample.csv', separator=",")

# %% [markdown]
# ##### save negative posts to csv from the text files

# %%
data_dict = {'posts': []}

with open(data_dir+'gpt3_neg_sample.txt') as f:
    for line in f.readlines():
        if line[0] == 'p':
            post = line.split('post : ')[-1].split('\n')[0]
            data_dict['posts'].append(post)

neg_df = pl.from_dict(data_dict)
neg_df.write_csv(data_dir+'gpt3_neg_sample.csv', separator=",")

# %% [markdown]
# ##### chatgpt to find metaphors on the samples

# %%
# gpt3.5 client
client = OpenAI(api_key="api_key")  # "api_key"

# %% [markdown]
# ##### load data

# %%
pos_df = pl.read_csv(data_dir+'gpt3_pos_sample.csv')
posts = pos_df['posts'].to_list()

# %%
neg_df = pl.read_csv(data_dir+'gpt3_neg_sample.csv')
posts = neg_df['posts'].to_list()

# %%
temp = 0.5
all_responses = []

bar = tqdm(range(len(posts)))
for post in posts:
    response = client.chat.completions.create(
        model="gpt-3.5-turbo",
        response_format={ "type": "json_object" },
        seed=20,
        temperature=temp,
        messages=[
            {
                "role": "system",
                "content": "You will be provided with a Reddit post title, and your task is to identify if the post contains a sports metaphor or not. Note that sports related words may be used in a nonmetaphorical way, do not label such cases as sports metaphors. If the text does contain a sports metaphor, identify the sports metaphor word or phrase and provide a max 10 word explanation. Provide the answer in a JSON format with the following keys, contains_sports_metaphor (true/false), sports_metaphor, explanation."
            },
            {
                "role": "user",
                "content": post
            }
        ],
    )
                
    obj = json.loads(response.json())
    resp_json = json.loads(obj["choices"][0]["message"]["content"])
    resp_json["post"] = post
    all_responses.append(resp_json)
    bar.update(1)
# Out:
#   0%|          | 0/201 [00:00<?, ?it/s]

# %%
all_responses
# Out:
# [{'contains_sports_metaphor': False,
#   'sports_metaphor': None,
#   'explanation': None,
#   'post': 'How Donald Trump Bankrupted His Casinos, Left Contractors Unpaid, Ruined Investors &amp; Made Millions (video)'},
#  {'contains_sports_metaphor': False,
#   'post': 'Just getting back from the rally at University of New Hampshire...'},
#  {'contains_sports_metaphor': False,
#   'sports_metaphor': None,
#   'explanation': None,
#   'post': 'Trump privately blamed Black Americans for lacking initiative: report'},
#  {'contains_sports_metaphor': False,
#   'sports_metaphor': '',
#   'explanation': '',
#   'post': 'Shooting Survivor: CNN Gave Me "Scripted Question" After Denying Question About Armed Guards'},
#  {'contains_sports_metaphor': False,
#   'sports_metaphor': None,
#   'explanation': None,
#   'post': 'Are Trump supporters evil, or just wrong? Political scientists struggle with morality'},
#  {'contains_sports_metaphor': False,
#   'post': 'Leicester blast triggers police alert'},
#  {'contains_sports_metaphor': False,
#   'post': 'Now would be a great time for Sean Hannity to revisit his Seth Rich lies'},
#  {'contains_sports_metaphor': False,
#   'sports_metaphor': None,
#   'explanation': None,
#   'post': "Mexican Foreign Minister: Mexico's Violence Is Product of U.S. Gun Laws"},
#  {'contains_sports_metaphor': False,
#   'sports_metaphor': None,
#   'explanation': None,
#   'post': "Carl Bernstein: Trump is a 'war criminal'"},
#  {'contains_sports_metaphor': False,
#   'sports_metaphor': None,
#   'explanation': None,
#   'post': 'Wife of Missouri governor tests positive for COVID-19'},
#  {'contains_sports_metaphor': False,
#   'sports_metaphor': None,
#   'explanation': None,
#   'post': "OLake Examines Lauren Chen's Shockingly Stupid Take on Anti-Asian Hate Crimes."},
#  {'contains_sports_metaphor': False,
#   'sports_metaphor': None,
#   'explanation': None,
#   'post': 'Terrorism expert: Trump remains a major ‘national security’ threat to the United States'},
#  {'contains_sports_metaphor': False,
#   'post': 'Israeli military prepares for possibility Trump will strike Iran'},
#  {'contains_sports_metaphor': False,
#   'sports_metaphor': None,
#   'explanation': None,
#   'post': 'British forces head for Ukraine as David Cameron issues warning to Vladimir Putin'},
#  {'contains_sports_metaphor': False,
#   'post': 'Unathi Kwaza RT from Belyy Richard James: 100%'},
#  {'contains_sports_metaphor': False,
#   'sports_metaphor': None,
#   'explanation': None,
#   'post': 'Top Koch Network officials vent frustration with White House, GOP-led Congress'},
#  {'contains_sports_metaphor': False,
#   'post': 'Saudis Spent $270K At Trump Hotel In Lobbying Campaign Against 9/11 Bill'},
#  {'contains_sports_metaphor': False,
#   'sports_metaphor': None,
#   'explanation': None,
#   'post': "Why Andrew Yang's UBI Is Worth a Look for Dems in 2020"},
#  {'contains_sports_metaphor': False,
#   'sports_metaphor': '',
#   'explanation': '',
#   'post': 'Pelosi left with no good options for how to address Rep. Ilhan Omar’s controversial Israel comments'},
#  {'contains_sports_metaphor': False,
#   'sports_metaphor': '',
#   'explanation': '',
#   'post': 'Florida Gov signs law requiring students, faculty be asked to declare their political beliefs'},
#  {'contains_sports_metaphor': False,
#   'sports_metaphor': None,
#   'explanation': None,
#   'post': 'Unathi Kwaza: It is being foisted on the majority to establish discrimination against “whites,” in order to destroy a political contingent deemed inimical to the Democratic Party–run state. It is a means for marginalizing oppositional elements and driving others into the voting ranks of the'},
#  {'contains_sports_metaphor': False,
#   'sports_metaphor': None,
#   'explanation': None,
#   'post': 'Roberts Supreme Court Rules In Favor Of Dark Money Groups'},
#  {'contains_sports_metaphor': False,
#   'sports_metaphor': None,
#   'explanation': None,
#   'post': 'Obama considering post-presidential digital media career, sources say'},
#  {'contains_sports_metaphor': False,
#   'sports_metaphor': None,
#   'explanation': None,
#   'post': 'There is a key difference between Gorsuch and every other nominee'},
#  {'contains_sports_metaphor': False,
#   'post': 'What Bernie Sanders Doesn’t Understand About Germany’s Free College'},
#  {'contains_sports_metaphor': False,
#   'post': 'This is a repudiation of Corbynism. Labour needs to ditch the politics of the sect - This should scare every democrat running to the left - The electorate said Bullshite'},
#  {'contains_sports_metaphor': False,
#   'sports_metaphor': '',
#   'explanation': '',
#   'post': 'Jokingly asked if he thinks wind turbines cause cancer, @BetoORourke says “I don’t think that wind turbines cause cancer, in fact I think they cause jobs.”'},
#  {'contains_sports_metaphor': False,
#   'post': 'First Hillary Clinton Rally/Event - What To Expect?'},
#  {'contains_sports_metaphor': False,
#   'sports_metaphor': '',
#   'explanation': '',
#   'post': 'Psychoactive Substances Act delayed while the Home Office works out what it has banned'},
#  {'contains_sports_metaphor': False,
#   'post': 'Montreal university takes hard line against class disruptions as student strikes return'},
#  {'contains_sports_metaphor': False,
#   'sports_metaphor': '',
#   'explanation': '',
#   'post': 'Trump lobbies moderators ahead of debate'},
#  {'contains_sports_metaphor': False,
#   'post': 'Trump’s new NAFTA faces uphill battle in Congress'},
#  {'contains_sports_metaphor': False,
#   'sports_metaphor': '',
#   'explanation': '',
#   'post': 'Michael Avenatti Turns Radioactive As Liberals Blame Porn Lawyer For Kavanaugh Confirmation | Zero Hedge'},
#  {'contains_sports_metaphor': False,
#   'post': 'Trump action on health care could cost Planned Parenthood'},
#  {'contains_sports_metaphor': False,
#   'post': 'Mueller Report: A narrative of obstruction laid plain'},
#  {'contains_sports_metaphor': False,
#   'sports_metaphor': '',
#   'explanation': '',
#   'post': 'Franken urged to reverse his resignation'},
#  {'contains_sports_metaphor': False,
#   'post': 'Facebook accused of anti conservative bias due to its efforts to counter misinformation. That pretty much tells you all you need to know about modern conservatism. Misinformation and victimhood.'},
#  {'contains_sports_metaphor': False,
#   'sports_metaphor': None,
#   'explanation': None,
#   'post': 'covid-19-dashboard-december-22-2020'},
#  {'contains_sports_metaphor': False,
#   'sports_metaphor': None,
#   'explanation': None,
#   'post': "Coretta Scott King's Letter To Be Blasted Into McConnell's Home With Bullhorn."},
#  {'contains_sports_metaphor': False,
#   'post': 'Thing that is the opposite of capitalism is somehow the result of capitalism [+23]'},
#  {'contains_sports_metaphor': False,
#   'sports_metaphor': None,
#   'explanation': None,
#   'post': 'Andrew Yang Interview On CNN With Chris Cuomo 8/29/19'},
#  {'contains_sports_metaphor': False,
#   'post': 'U.S. Senate Republicans to Issue Revised Health Bill to Win Support: Aide'},
#  {'contains_sports_metaphor': False,
#   'post': 'White House seeks $18B to extend border wall over next 10 years'},
#  {'contains_sports_metaphor': False,
#   'post': "Nolte: U.S. Conference of Bishops' Ludicrous Response to Steve Bannon's '60 Minutes' Interview - Breitbart"},
#  {'contains_sports_metaphor': False,
#   'sports_metaphor': None,
#   'explanation': None,
#   'post': 'Australian Researchers Tout New ‘Wonder Drug’ As Potential Cure For Coronavirus Patients'},
#  {'contains_sports_metaphor': False,
#   'post': 'U.S. to carry out 13th and final execution under Trump administration'},
#  {'contains_sports_metaphor': False,
#   'sports_metaphor': None,
#   'explanation': None,
#   'post': "Maxine Waters wins media award, uses speech to bad-mouth Trump to newspaper publishers: 'I don't like him'"},
#  {'contains_sports_metaphor': False,
#   'sports_metaphor': None,
#   'explanation': None,
#   'post': 'Biden Nominates Anti-Gun Fanatic to Run the Bureau of Alcohol, Tobacco, Firearms and Explosives'},
#  {'contains_sports_metaphor': False,
#   'sports_metaphor': '',
#   'explanation': '',
#   'post': 'Get out and vote NJ pedes'},
#  {'contains_sports_metaphor': False,
#   'post': 'Romney Says $2K Checks Too Expensive, Despite Relief Bill Containing Billions for Foreigners -- “Someone’s got to pay for that. We can’t just have free money.”'},
#  {'contains_sports_metaphor': False,
#   'post': "McConnell signals Senate Republicans don't want bigger Covid relief bill before election"},
#  {'contains_sports_metaphor': False,
#   'post': 'Pete Buttigieg on his Big Idea with Harry Smith | NBC Nightly News'},
#  {'contains_sports_metaphor': False,
#   'sports_metaphor': None,
#   'explanation': None,
#   'post': 'Lauren Boebert blasted for turning charity event into QAnon conspiracy attack'},
#  {'contains_sports_metaphor': False,
#   'sports_metaphor': None,
#   'explanation': None,
#   'post': 'President Trump’s habitual flip-floppery, in 7 steps'},
#  {'contains_sports_metaphor': False,
#   'sports_metaphor': None,
#   'explanation': None,
#   'post': 'Black college lacrosse player is arrested for racist N-word and swastika graffiti'},
#  {'contains_sports_metaphor': False,
#   'sports_metaphor': None,
#   'explanation': None,
#   'post': 'Partially vaccinated Canadians can socialize outdoors this summer, Tam says | CBC News'},
#  {'contains_sports_metaphor': False,
#   'sports_metaphor': None,
#   'explanation': None,
#   'post': 'Laura Poitras says she’s been fired by First Look Media over Reality Winner controversy. Now she’s questioning the company’s integrity.'},
#  {'contains_sports_metaphor': False,
#   'post': "The 3 CNN staffers that got fired might have been Trump's team testing the waters."},
#  {'contains_sports_metaphor': False,
#   'sports_metaphor': None,
#   'explanation': None,
#   'post': 'Mike Lindell Visits Oval Office, Appears to Urge Martial Law (Do you now UNDERSTAND what you’re Dealing with, Boys &amp; Girls???)'},
#  {'contains_sports_metaphor': False, 'post': 'Why Yang would beat Trump'},
#  {'contains_sports_metaphor': False,
#   'sports_metaphor': None,
#   'explanation': None,
#   'post': 'Bernie gains 8 delegates! JUST 795 MORE TO GO TO CATCH UP TO CLINTON!'},
#  {'contains_sports_metaphor': False,
#   'sports_metaphor': None,
#   'explanation': None,
#   'post': 'Iceland sentences 26 corrupt bankers to 74 years in prison'},
#  {'contains_sports_metaphor': False,
#   'sports_metaphor': '',
#   'explanation': '',
#   'post': "Michael Moore fires back after Trump claimed his show was 'forced to close'"},
#  {'contains_sports_metaphor': False,
#   'sports_metaphor': None,
#   'explanation': None,
#   'post': 'WATCH: CNN Repeatedly Attacks Trump For Paying Respects To George H.W. Bush'},
#  {'contains_sports_metaphor': False,
#   'sports_metaphor': None,
#   'explanation': None,
#   'post': 'Trump\'s Univision Complaint: Univision doesn\'t have a right to buy out their pageant contract because "Mr. Trump\'s longstanding views or statements . . . are protected by the first amendment and have been echoed by many in this country" [pdf]'},
#  {'contains_sports_metaphor': False,
#   'post': 'Second Weekly National Vice Presidential Address'},
#  {'contains_sports_metaphor': False, 'post': 'Phone Banking Tips and Tricks'},
#  {'contains_sports_metaphor': False,
#   'sports_metaphor': None,
#   'explanation': None,
#   'post': "John McCain's granddaughter endorses Hillary Clinton: 'I've been nursing a grudge'"},
#  {'contains_sports_metaphor': False,
#   'post': "Bernie Sanders Gets Hero's Welcome in Home State of Vermont"},
#  {'contains_sports_metaphor': False,
#   'post': 'COP24 climate talks end in agreement, barely'},
#  {'contains_sports_metaphor': False,
#   'sports_metaphor': None,
#   'explanation': None,
#   'post': 'KEK : Trump Reportedly Keeps Showing White House Guests Where Bill Clinton and Monica Lewinsky Had Sex'},
#  {'contains_sports_metaphor': False,
#   'sports_metaphor': None,
#   'explanation': None,
#   'post': 'APNewsBreak: AP Sources: US ends Syria stabilization funding'},
#  {'contains_sports_metaphor': False,
#   'sports_metaphor': None,
#   'explanation': None,
#   'post': 'Trump Said No Tear Gas Used to Clear Protesters for Photo Op. These Canisters Suggest Otherwise.'},
#  {'contains_sports_metaphor': False,
#   'post': 'Joe Biden sees fundraising surge in wake of George Floyd’s death and Trump’s response to protests'},
#  {'contains_sports_metaphor': False,
#   'sports_metaphor': None,
#   'explanation': None,
#   'post': 'Trump Removes FBI Director James Comey (Bloomberg)'},
#  {'contains_sports_metaphor': False,
#   'sports_metaphor': None,
#   'explanation': None,
#   'post': 'Report: McConnell Feared Trump Would Pull Another Jan. 6 at Biden’s Inauguration'},
#  {'contains_sports_metaphor': False,
#   'sports_metaphor': None,
#   'explanation': None,
#   'post': 'Open Letter to the U.K government to free Julian Assange'},
#  {'contains_sports_metaphor': False,
#   'sports_metaphor': '',
#   'explanation': '',
#   'post': "Surprise! Women's Marchers Hired Armed Guards For Their Protest Against The NRA"},
#  {'contains_sports_metaphor': False,
#   'post': 'Theresa May survives confidence vote'},
#  {'contains_sports_metaphor': False,
#   'sports_metaphor': None,
#   'explanation': None,
#   'post': "GOP governor in North Dakota gives emotional plea against 'mask shaming'"},
#  {'contains_sports_metaphor': False,
#   'post': "The parenting problem the government can't fix"},
#  {'contains_sports_metaphor': False,
#   'post': "Mueller's probe shifts to Trump's presidency"},
#  {'contains_sports_metaphor': False,
#   'post': "Donald Trump Jr. RT from Francis Brennan (Text TRUMP to 88022): “Charlamagne tha God says Biden an 'intricate part' of system that 'needs to be dismantled': 'What have you done for me, lately?'”"},
#  {'contains_sports_metaphor': False,
#   'sports_metaphor': None,
#   'explanation': None,
#   'post': "Jerm: @Clint_ZA @JasonKlopper5 @WMerthon Basically, anybody who questions the official narrative, is a conspiracy theorist, then. It took decades to uncover the tobacco industry's conspiracy surrounding cancer causation. You would have had a field day labelling everyone back then."},
#  {'contains_sports_metaphor': False,
#   'sports_metaphor': '',
#   'explanation': '',
#   'post': '1 Verdict, Then 6 Police Killings Across America In 24 hours'},
#  {'contains_sports_metaphor': False,
#   'sports_metaphor': None,
#   'explanation': None,
#   'post': 'Applying Marxist theory to non-capitalist/pre-capitalist economies'},
#  {'contains_sports_metaphor': False,
#   'sports_metaphor': None,
#   'explanation': None,
#   'post': 'Kentucky’s GOP Governor Says Teacher Protests Enable Child Sexual Assault'},
#  {'contains_sports_metaphor': False,
#   'sports_metaphor': None,
#   'explanation': None,
#   'post': 'Email Leak Exposes Trump Tower Russian’s Dirty Lobbying Operations - According to leaked emails from Natalia Veselniskaya, Russia’s disinformation campaign may have broken U.S. law &amp; exposed details of a witness who later fell from a window.'},
#  {'contains_sports_metaphor': False,
#   'sports_metaphor': None,
#   'explanation': None,
#   'post': "2020's Problems Don't Die With 2020"},
#  {'contains_sports_metaphor': False,
#   'post': 'U.S. Senate agenda includes Biden investment plan, debt limit, voting rights -Schumer'},
#  {'contains_sports_metaphor': False,
#   'post': "There's no England now, UKIP is fighting to stop mass immigration."},
#  {'contains_sports_metaphor': False,
#   'sports_metaphor': '',
#   'explanation': '',
#   'post': 'Unathi Kwaza: @sandidakar Oh my word, that long��'},
#  {'contains_sports_metaphor': False,
#   'sports_metaphor': None,
#   'explanation': None,
#   'post': 'Warrants not required for police to get your cell phone cell-site records'},
#  {'contains_sports_metaphor': False,
#   'sports_metaphor': None,
#   'explanation': None,
#   'post': 'With Regards to the Recent Earthquake in Chesapeake'},
#  {'contains_sports_metaphor': False,
#   'sports_metaphor': '',
#   'explanation': '',
#   'post': 'Behind the Whistle-Blower Case, a Long-Held Trump Grudge Toward Ukraine'},
#  {'contains_sports_metaphor': False,
#   'post': 'GOP calls grow to end Russia investigations this year'},
#  {'contains_sports_metaphor': False,
#   'sports_metaphor': None,
#   'explanation': None,
#   'post': 'TSA Investigation Finds 73 Workers on U.S.’s Terrorist Watchlist'},
#  {'contains_sports_metaphor': False,
#   'sports_metaphor': None,
#   'explanation': None,
#   'post': 'Mandatory vaccination against COVID for certain categories imposed in 25 Russian regions'},
#  {'contains_sports_metaphor': False,
#   'sports_metaphor': None,
#   'explanation': None,
#   'post': 'Sign this petition for TYT, a true progressive online show, to host a fair democratic debate in the future! This will help many people to be exposed to Bernie which might be potentially very good!'},
#  {'contains_sports_metaphor': False,
#   'sports_metaphor': None,
#   'explanation': None,
#   'post': 'BREAKING: KRIS KOBACH likely Attorney General'},
#  {'contains_sports_metaphor': False,
#   'sports_metaphor': None,
#   'explanation': None,
#   'post': 'Is Trump Capitalizing on the FBI’s Rebuke of Clinton?'},
#  {'contains_sports_metaphor': False,
#   'sports_metaphor': None,
#   'explanation': None,
#   'post': 'Massive genetic study shows coronavirus mutating and potentially evolving amid rapid U.S. spread'},
#  {'contains_sports_metaphor': False,
#   'post': 'Both Candidates Agreed on Bashing the Left'},
#  {'contains_sports_metaphor': False,
#   'sports_metaphor': None,
#   'explanation': None,
#   'post': "Oakland's mayor just warned the sanctuary city about a potential ICE raid"},
#  {'contains_sports_metaphor': False,
#   'post': "Donald Trump to Russia: hack and publish Hillary Clinton's 'missing' emails"},
#  {'contains_sports_metaphor': False,
#   'post': 'What are differences / similarities between anarchy and some strands of libertarianism? Thanks.'},
#  {'contains_sports_metaphor': False,
#   'sports_metaphor': None,
#   'explanation': None,
#   'post': 'President Trump: "Landing in Montana now to support Matt Rosendale for U.S. Senate! #MAGA https://t.co/0MIEyWxMbW"'},
#  {'contains_sports_metaphor': False,
#   'sports_metaphor': None,
#   'explanation': None,
#   'post': 'Despite all his fuming about fakes: "Trump campaign really did pay fake supporters to attend 2015 campaign launch, aide admits"'},
#  {'contains_sports_metaphor': False,
#   'sports_metaphor': None,
#   'explanation': None,
#   'post': 'CNN’s own source says Michael Cohen story is fake news, but network stands by it — RT US News'},
#  {'contains_sports_metaphor': False,
#   'sports_metaphor': None,
#   'explanation': None,
#   'post': 'Libertarianism with cows'},
#  {'contains_sports_metaphor': False,
#   'sports_metaphor': None,
#   'explanation': None,
#   'post': 'Jeremy Corbyn Facing Backlash Over Policy On Self-Identifying Trans Women'},
#  {'contains_sports_metaphor': False,
#   'sports_metaphor': None,
#   'explanation': None,
#   'post': 'Conservative MP Mark Pritchard defends PM in tax row'},
#  {'contains_sports_metaphor': False,
#   'post': 'Pelosi requests removal of Confederate statues in Capitol'},
#  {'contains_sports_metaphor': False,
#   'sports_metaphor': None,
#   'explanation': None,
#   'post': 'Reports Suggest U.S. Harboring Top Chinese Official ‘Close To’ Xi Jinping, Gave Info On Pandemic Origin'},
#  {'contains_sports_metaphor': False,
#   'sports_metaphor': '',
#   'explanation': '',
#   'post': 'The U.S. Needs to Face Up to Its Long History of Election Meddling'},
#  {'contains_sports_metaphor': False,
#   'sports_metaphor': '',
#   'explanation': '',
#   'post': "Cutting out the middleman--Zephyr Teachout challenges her opponent's billionaire SuperPAC backer to a debate."},
#  {'contains_sports_metaphor': False,
#   'sports_metaphor': '',
#   'explanation': '',
#   'post': "Abbott says campus carry will make attackers 'think twice' about targeting Texas schools"},
#  {'contains_sports_metaphor': False,
#   'sports_metaphor': '',
#   'explanation': '',
#   'post': "Unathi Kwaza: Parks Tau failed as a mayor and now the ANC thinks he'll be a successful MEC for Economic Development. U can't make the shit up������������"},
#  {'contains_sports_metaphor': False,
#   'sports_metaphor': None,
#   'explanation': None,
#   'post': 'Unathi Kwaza RT from Silna: @michael_kaniel @Unathi_Kwaza This ��'},
#  {'contains_sports_metaphor': False,
#   'sports_metaphor': '',
#   'explanation': '',
#   'post': '3 Reasons the $15 Minimum Wage Is a Bad Way to Help the Poor'},
#  {'contains_sports_metaphor': False,
#   'sports_metaphor': None,
#   'explanation': None,
#   'post': 'This is how Americans say they would spend possible second economic stimulus check'},
#  {'contains_sports_metaphor': False,
#   'post': 'Trump and pardons: How many people could be granted clemency?'},
#  {'contains_sports_metaphor': False,
#   'sports_metaphor': '',
#   'explanation': '',
#   'post': 'Nancy Pelosi Unhinged: Scolds CNN’s Wolf Blitzer in Tense Segment on Stimulus; “You don’t know what you’re talking about!”'},
#  {'contains_sports_metaphor': False,
#   'sports_metaphor': None,
#   'explanation': None,
#   'post': 'Minimum Wage is a Trojan Horse'},
#  {'contains_sports_metaphor': False,
#   'post': 'Bernie needs to make sure he does really good in tomorrows debate'},
#  {'contains_sports_metaphor': False,
#   'sports_metaphor': None,
#   'explanation': None,
#   'post': 'Finland is fooked! Makes 34 year old woman "the country\'s third female in the top role, but also the world\'s youngest leader"'},
#  {'contains_sports_metaphor': False,
#   'sports_metaphor': None,
#   'explanation': None,
#   'post': "White House coronavirus advisers Fauci and Birx reportedly warned about the risks of Trump's Tulsa rally, but he's going ahead with it anyway"},
#  {'contains_sports_metaphor': False,
#   'post': "New batch of Hillary Clinton emails will hit the Internet on New Year's Eve – when no one is paying attention"},
#  {'contains_sports_metaphor': False,
#   'post': 'Voter Registration Doesn’t Point to Huge Iowa Surge'},
#  {'contains_sports_metaphor': False,
#   'sports_metaphor': '',
#   'explanation': '',
#   'post': "Facebook employees report 'pattern of preferential treatment' for conservatives who spread misinformation"},
#  {'contains_sports_metaphor': False,
#   'post': 'Libertarians built a crypto mecca in New Hampshire - then Feds tore it down'},
#  {'contains_sports_metaphor': False,
#   'sports_metaphor': None,
#   'explanation': None,
#   'post': "Is this case really going until December? It seems like quid pro quo got denied, extortion got denied, and next they are going on bribery. It doesn't seem like impeachment is successful at all"},
#  {'contains_sports_metaphor': False,
#   'sports_metaphor': None,
#   'explanation': None,
#   'post': 'Obama set the immigration trap, and the GOP walked in: "Republicans are caught in a trap. They\'re fighting for a policy most of them don\'t believe in as a way, they think, to strike back at the president"'},
#  {'contains_sports_metaphor': False,
#   'sports_metaphor': None,
#   'explanation': None,
#   'post': "Nick Clegg: Conservatives 'arrogant' over TV debates"},
#  {'contains_sports_metaphor': False,
#   'sports_metaphor': None,
#   'explanation': None,
#   'post': 'Lecture - "Your Next Government?: From the Nation State to Stateless Nations" | Prof. Tom W. Bell'},
#  {'contains_sports_metaphor': False,
#   'post': 'Black First Land First, A South African Revolutionary Socialist Political Party, Wants To Take Back "Their" Land Through Violent Means!'},
#  {'contains_sports_metaphor': False,
#   'sports_metaphor': None,
#   'explanation': None,
#   'post': 'Trump goes nuclear on Cuban immigration'},
#  {'contains_sports_metaphor': False,
#   'sports_metaphor': None,
#   'explanation': None,
#   'post': 'Reset The Clock: Man kills 3 people in shootings in downtown Fresno'},
#  {'contains_sports_metaphor': False,
#   'sports_metaphor': None,
#   'explanation': None,
#   'post': 'I will stand down and resign my membership of the #LibDems unless the party apologises to @ThatTimWalker Full statement below.'},
#  {'contains_sports_metaphor': False,
#   'post': 'Trump urges UN to stop Iran getting nuclear bomb'},
#  {'contains_sports_metaphor': False,
#   'post': 'Chemical emergency in Laporte Texas'},
#  {'contains_sports_metaphor': False, 'post': 'Brexit and Northern Ireland'},
#  {'contains_sports_metaphor': False,
#   'sports_metaphor': None,
#   'explanation': None,
#   'post': "Fired for refusing the vaccine? Don't count on unemployment benefits"},
#  {'contains_sports_metaphor': False,
#   'sports_metaphor': None,
#   'explanation': None,
#   'post': "Poll: 55% approve of Trump's temporary immigration ban"},
#  {'contains_sports_metaphor': False,
#   'sports_metaphor': '',
#   'explanation': '',
#   'post': 'President Trump on Maury 16 years ago No wonder he won the election, considering the opposition'},
#  {'contains_sports_metaphor': False,
#   'sports_metaphor': '',
#   'explanation': '',
#   'post': "Cruz calls for anyone 'involved in voter fraud' to be prosecuted and jailed during Georgia rally"},
#  {'contains_sports_metaphor': False,
#   'sports_metaphor': None,
#   'explanation': None,
#   'post': 'Nigel should not have used HIV as a political argument'},
#  {'contains_sports_metaphor': False,
#   'post': '19 years old. “Blood clots all over” A result from a NO JAB, NO JOB policy. Listen to her story, her New Normal as she calls it.'},
#  {'contains_sports_metaphor': False,
#   'sports_metaphor': None,
#   'explanation': None,
#   'post': 'Kinzinger: McCarthy and Jordan should face Capitol attack subpoenas – but maybe not Trump'},
#  {'contains_sports_metaphor': False, 'post': 'Weekly Open Discussion'},
#  {'contains_sports_metaphor': False,
#   'post': 'GOP Chairwoman: "The RNC smashed another fundraising record last month. Between @realDonaldTrump\'s accomplishments and our grassroots infrastructure, Republicans are going to be unstoppable in 2020!"'},
#  {'contains_sports_metaphor': False,
#   'sports_metaphor': None,
#   'explanation': None,
#   'post': 'THE MITTENS PLAN. Bernie Sanders: Here’s How To Get Student Loan Cancellation And $2,000 Stimulus Checks Without Republicans'},
#  {'contains_sports_metaphor': False,
#   'sports_metaphor': None,
#   'explanation': None,
#   'post': 'Chipotle claims they\'re reconsidering firing of manager after old tweets like "man I think Chipotle catching up to us fam… should we change locations" surface'},
#  {'contains_sports_metaphor': False,
#   'sports_metaphor': None,
#   'explanation': None,
#   'post': "Fox News host Sean Hannity dismisses Roy Moore's sexual misconduct allegations by saying it was 'consensual'"},
#  {'contains_sports_metaphor': False,
#   'sports_metaphor': None,
#   'explanation': None,
#   'post': 'TIL: 8 U.S. Code § 1481 states that you lose citizenship for committing acts of treason or war against the US (ISIS bride BTFO!)'},
#  {'contains_sports_metaphor': False,
#   'sports_metaphor': None,
#   'explanation': None,
#   'post': 'US saw record increase in murders in 2020'},
#  {'contains_sports_metaphor': False,
#   'sports_metaphor': None,
#   'explanation': None,
#   'post': 'History Lesson: Bernie Sanders is no ‘Communist,’ and ‘Democratic Socialists’ are as American as Apple Pie.'},
#  {'contains_sports_metaphor': False, 'post': '[deleted by user]'},
#  {'contains_sports_metaphor': False,
#   'post': 'Denver votes to legalize psilocybin mushrooms'},
#  {'contains_sports_metaphor': False,
#   'sports_metaphor': None,
#   'explanation': None,
#   'post': "Berlin's Madame Tussauds places wax Trump in a dumpster ahead of election"},
#  {'contains_sports_metaphor': False, 'post': 'Voter Suppression'},
#  {'contains_sports_metaphor': False,
#   'post': 'Mueller now investigating Democratic lobbyist Tony Podesta'},
#  {'contains_sports_metaphor': False,
#   'post': 'Republicans call Deb Haaland a ‘radical.’ Polls show their views on climate are out of the mainstream'},
#  {'contains_sports_metaphor': False,
#   'post': 'Funding bill gives $3 billion boost for NIH medical research'},
#  {'contains_sports_metaphor': False,
#   'post': 'Would you stop supporting Bernie Sanders if he changed his tune a little bit?'},
#  {'contains_sports_metaphor': False,
#   'post': 'Remembering the day the war ended.'},
#  {'contains_sports_metaphor': False,
#   'sports_metaphor': None,
#   'explanation': None,
#   'post': "Why does reddit think Bernie doesn't get covered by the media?"},
#  {'contains_sports_metaphor': False,
#   'sports_metaphor': None,
#   'explanation': None,
#   'post': "More Cabinet trouble for Trump? EPA chief lived in condo tied to lobbyist 'power couple'"},
#  {'contains_sports_metaphor': False,
#   'sports_metaphor': None,
#   'explanation': None,
#   'post': 'Michael Cohen’s Attorney May Be an Even Worse Lawyer Than He Is'},
#  {'contains_sports_metaphor': False,
#   'sports_metaphor': None,
#   'explanation': None,
#   'post': 'Rittenhouse VERDICT WATCH: Has Jury Foreperson Gone Rogue And Holding Back Acquittal?'},
#  {'contains_sports_metaphor': False,
#   'post': 'Roy Moore asks for donations to cover legal expenses'},
#  {'contains_sports_metaphor': False,
#   'sports_metaphor': None,
#   'explanation': None,
#   'post': 'In light of the French election loss ask yourself this, T_D'},
#  {'contains_sports_metaphor': False,
#   'sports_metaphor': None,
#   'explanation': None,
#   'post': "Tory MPs vow to stop Boris Johnson being suspended from the House of Commons over his 'freebie' Mustique trip with Carrie Symonds by rejecting the verdict of the standards watchdog"},
#  {'contains_sports_metaphor': False,
#   'sports_metaphor': '',
#   'explanation': '',
#   'post': "How The DEA Seized A College Student's Entire Life Savings, Without Charging Him With A Drug Crime"},
#  {'contains_sports_metaphor': False,
#   'sports_metaphor': None,
#   'explanation': None,
#   'post': "Sam Seder and Virgil Texas were discussing the lack of right wing podcasts on Chapo and you'll never guess what happened next..."},
#  {'contains_sports_metaphor': False,
#   'sports_metaphor': None,
#   'explanation': None,
#   'post': 'Obama’s Hawaii vacation is over, now it’s time for taxpayers to pay massive tab'},
#  {'contains_sports_metaphor': False,
#   'post': 'How can a libertarian be pro abortion?'},
#  {'contains_sports_metaphor': False,
#   'sports_metaphor': None,
#   'explanation': None,
#   'post': 'The United States and the United Kingdom are priority!'},
#  {'contains_sports_metaphor': False,
#   'sports_metaphor': None,
#   'explanation': None,
#   'post': 'Smollett threat letter called "enormous mistake" - Purported attack location identified - Federal charges "certain" - Legal source: "If they want to bury him, they can."'},
#  {'contains_sports_metaphor': False,
#   'sports_metaphor': None,
#   'explanation': None,
#   'post': 'South Dakota passes bill banning transgender athletes in women’s and girls’ sport'},
#  {'contains_sports_metaphor': False,
#   'sports_metaphor': None,
#   'explanation': None,
#   'post': 'How can socialism overcome the fact that many people are readily convinced to work against their own self-interests?'},
#  {'contains_sports_metaphor': False,
#   'sports_metaphor': None,
#   'explanation': None,
#   'post': 'Alice Marie Johnson leaves prison after Trump commutes sentence (one week after Trump met with Kardashian)'},
#  {'contains_sports_metaphor': False,
#   'sports_metaphor': None,
#   'explanation': None,
#   'post': "Why The Republicans Don't Have An Obamacare Replacement Plan"},
#  {'contains_sports_metaphor': False,
#   'sports_metaphor': None,
#   'explanation': None,
#   'post': "Cop charged after bodycam footage shows 'horrible use of force': Police chief"},
#  {'contains_sports_metaphor': False,
#   'sports_metaphor': None,
#   'explanation': None,
#   'post': 'Paul: Benghazi should ‘forever preclude’ Hillary from presidency'},
#  {'contains_sports_metaphor': False,
#   'post': 'Kurl: Canada is changing. Abusing people of colour in public life has to stop'},
#  {'contains_sports_metaphor': False,
#   'post': 'New York City subway shooter is an MS-13 gang member, report says'},
#  {'contains_sports_metaphor': False,
#   'post': 'Jan. 6 panel threatens Meadows with contempt'},
#  {'contains_sports_metaphor': False,
#   'sports_metaphor': None,
#   'explanation': None,
#   'post': 'Have The Times Finally Caught Up With Bernie Sanders?'},
#  {'contains_sports_metaphor': False,
#   'sports_metaphor': None,
#   'explanation': None,
#   'post': 'DJ Lewis on Twitter: "TRUMP should not debate FIX IS IN Romney Pres/Ryan VP here is the filed proof https://t.co/OvUENP0d44"'},
#  {'contains_sports_metaphor': False,
#   'sports_metaphor': None,
#   'explanation': None,
#   'post': 'US employment up by 223,000 in June'},
#  {'contains_sports_metaphor': False,
#   'sports_metaphor': None,
#   'explanation': None,
#   'post': "Liberal activists who settled for Bernie Sanders last year say it's time for Elizabeth Warren to run for president."},
#  {'contains_sports_metaphor': False,
#   'sports_metaphor': None,
#   'explanation': None,
#   'post': 'Capitol riot defendants shared history of financial probelms: WaPo'},
#  {'contains_sports_metaphor': False,
#   'post': 'New York City Sets Covid-19 Vaccine Mandate for Private-Sector Workers'},
#  {'contains_sports_metaphor': False,
#   'post': 'Gay Rights Advocates Stage Massive Protest Outside Trump Tower'},
#  {'contains_sports_metaphor': False,
#   'post': 'New analysis undercuts the White House argument that tax reform benefits the middle class'},
#  {'contains_sports_metaphor': False,
#   'sports_metaphor': None,
#   'explanation': None,
#   'post': 'Republicans Will Have Their Revenge on Democrats for the January 6 Committee'},
#  {'contains_sports_metaphor': False,
#   'sports_metaphor': None,
#   'explanation': None,
#   'post': 'First-ever bill on Palestinian human rights introduced in Congress'},
#  {'contains_sports_metaphor': False,
#   'sports_metaphor': None,
#   'explanation': None,
#   'post': 'Treasury chief a Bond villain? Mnuchin OK with comparison'},
#  {'contains_sports_metaphor': False,
#   'sports_metaphor': None,
#   'explanation': None,
#   'post': 'Joseph Stiglitz (2014) - Why Capitalism is Failing.'},
#  {'contains_sports_metaphor': False,
#   'sports_metaphor': None,
#   'explanation': None,
#   'post': 'Donald Trump Jr. on Twitter: This is really something coming from a publisher who doesn’t fire an executive editor who was caught trying to take down a President with “racism!” after “Russia!” didn’t work. Flagrant, unchecked bias in the media is the threat to real journalism.'}]

# %%
neg_meta = []
neg_non_meta = []

for response in all_responses:
    if response['contains_sports_metaphor']:
        neg_meta.append({'post': response['post'], 'meta': response['sports_metaphor']})
    else:
        neg_non_meta.append({'post': response['post']})

# %%
len(neg_meta)
# Out:
# 0

# %%
len(neg_non_meta)
# Out:
# 201

# %%
meta = []
non_meta = []

for response in all_responses:
    if response['contains_sports_metaphor']:
        meta.append({'post': response['post'], 'meta': response['sports_metaphor']})
    else:
        non_meta.append({'post': response['post']})

# %%
len(non_meta)
# Out:
# 29

# %%
len(meta)
# Out:
# 172

# %% [markdown]
# ##### added results after running gpt on positive and negative matches from earlier separately

# %%
meta = meta + neg_meta
non_meta = non_meta + neg_non_meta

# %%
len(meta)
# Out:
# 172

# %%
len(non_meta)
# Out:
# 230

# %%
with open(data_dir+'gpt3_pos_sample_5.txt', 'w') as f:
    for item in meta:
        f.write('post : {}'.format(item['post']))
        f.write('\n')
        f.write('meta : {}'.format(item['meta']))
        f.write('\n')
        f.write('\n')

# %%
with open(data_dir+'gpt3_neg_sample_5.txt', 'w') as f:
    for item in non_meta:
        f.write('post : {}'.format(item['post']))
        f.write('\n')
        f.write('\n')
